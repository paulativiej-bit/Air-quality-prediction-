# %% [markdown]
# <a href="https://colab.research.google.com/github/paulativiej-bit/Air-quality-prediction-/blob/main/Air_quality_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
